# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data
merged_citrus = pd.read_excel('/Users/zoekim/Desktop/l3/aroma_result/citrus/csv/merged_citrus_v2.xlsx')
merged_citrus = merged_citrus.iloc[:, 1:7]

# Sort by receptor and set receptor as index
merged_citrus_sorted = merged_citrus.sort_values(by='Receptor').set_index('Receptor')

# Generate the clustermap with adjusted parameters
plt.figure(figsize=(15, 50))
clustermap = sns.clustermap(
    merged_citrus_sorted[['Citral', 'Decyl Acetate', 'Limonene', 'Phenylacetic', 'Naringin']],
    annot=False,
    cmap='coolwarm',
    linewidths=.5,
    linecolor='black',
    figsize=(15, 50)
)

# Rotate y-tick labels for better visibility
plt.setp(clustermap.ax_heatmap.yaxis.get_majorticklabels(), rotation=0, fontsize=8)

# Adjust the title position and axis labels
clustermap.fig.suptitle('Clustermap of Affinities Between Receptors and Citrus Ligands Grouped by Odor Characteristics', y=1.05)
clustermap.ax_heatmap.set_xlabel('Ligands')
clustermap.ax_heatmap.set_ylabel('Receptors')
plt.savefig("clustermap_citrus_v1.png", format="png")
plt.show()
# Out:
#           Citral  Decyl Acetate  Limonene  Phenylacetic  Naringin
# Receptor
# OR10A6      -5.0           -4.7      -5.9          -5.8      -7.6
# OR10C1      -4.5           -4.6      -5.4          -5.7      -9.0
# OR10G4      -5.2           -4.8      -5.9          -5.7      -8.4
# OR10G6      -5.1           -4.8      -5.9          -5.8      -7.6
# OR10G7      -5.3           -5.3      -6.3          -5.7     -10.2
# ...          ...            ...       ...           ...       ...
# OR8K3       -4.8           -5.0      -5.6          -6.3      -8.0
# OR9A2       -4.9           -5.1      -5.9          -6.1      -9.3
# OR9A4       -4.9           -5.8      -5.6          -5.4      -7.7
# OR9G4       -4.8           -4.6      -5.7          -5.6      -9.0
# OR9Q1       -5.2           -4.8      -6.5          -5.6      -8.1
#
# [224 rows x 5 columns]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data
merged_citrus = pd.read_excel('/Users/zoekim/Desktop/l3/aroma_result/citrus/csv/merged_citrus_v2.xlsx')
merged_citrus = merged_citrus.iloc[:, 1:7]

# Normalize the data
normalized_citrus = merged_citrus.copy()
columns_to_normalize = ['Citral', 'Decyl Acetate', 'Limonene', 'Phenylacetic', 'Naringin']

for column in columns_to_normalize:
    normalized_citrus[column] = (merged_citrus[column] - merged_citrus[column].min()) / (merged_citrus[column].max() - merged_citrus[column].min())

# Sort by receptor and set receptor as index
normalized_citrus_sorted = normalized_citrus.sort_values(by='Receptor').set_index('Receptor')

# Generate the clustermap with adjusted parameters
plt.figure(figsize=(15, 50))
clustermap = sns.clustermap(
    normalized_citrus_sorted[['Citral', 'Decyl Acetate', 'Limonene', 'Phenylacetic', 'Naringin']],
    annot=False,
    cmap='coolwarm',
    linewidths=.5,
    linecolor='black',
    figsize=(15, 50)
)

# Rotate y-tick labels for better visibility
plt.setp(clustermap.ax_heatmap.yaxis.get_majorticklabels(), rotation=0, fontsize=8)

# Adjust the title position and axis labels
clustermap.fig.suptitle('Clustermap of Affinities Between Receptors and Citrus Ligands Grouped by Odor Characteristics (Normalized)', y=1.05)
clustermap.ax_heatmap.set_xlabel('Ligands')
clustermap.ax_heatmap.set_ylabel('Receptors')

# Save the clustermap
plt.savefig("clustermap_citrus_normalized_v1.png", format="png")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data
merged_floral = pd.read_excel('/Users/zoekim/Desktop/l3/aroma_result/floral/csv/merged_floral_v1.xlsx')
merged_floral = merged_floral.iloc[:, 1:7]

# Sort by receptor and set receptor as index
merged_floral_sorted = merged_floral.sort_values(by='Receptor').set_index('Receptor')

# Generate the clustermap with adjusted parameters
plt.figure(figsize=(15, 50))
clustermap = sns.clustermap(
    merged_floral_sorted[['Citronellol', 'Geraniol', 'Hexyl Cinnamaldehyde', 'Linalool', 'Phenylethyl Alcohol']],
    annot=False,
    cmap='coolwarm',
    linewidths=.5,
    linecolor='black',
    figsize=(15, 50)
)

# Rotate y-tick labels for better visibility
plt.setp(clustermap.ax_heatmap.yaxis.get_majorticklabels(), rotation=0, fontsize=8)

# Adjust the title position and axis labels
clustermap.fig.suptitle('Clustermap of Affinities Between Receptors and Floral Ligands Grouped by Odor Characteristics', y=1.05)
clustermap.ax_heatmap.set_xlabel('Ligands')
clustermap.ax_heatmap.set_ylabel('Receptors')
plt.savefig("clustermap_floral_v1.png", format="png")
plt.show()

# %%
## fruity

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data
merged_fruity = pd.read_excel('/Users/zoekim/Desktop/l3/aroma_result/fruity/csv/merged_fruity_v1.xlsx')
merged_fruity = merged_fruity.iloc[:, 1:7]

# Sort by receptor and set receptor as index
merged_fruity_sorted = merged_fruity.sort_values(by='Receptor').set_index('Receptor')

# Generate the clustermap with adjusted parameters
plt.figure(figsize=(15, 50))
clustermap = sns.clustermap(
    merged_fruity_sorted[['Ethyl Butyrate', 'Ethyl Hexanoate', 'Hexanol', 'Hexyl Acetate', 'Isoamyl Acetate']],
    annot=False,
    cmap='coolwarm',
    linewidths=.5,
    linecolor='black',
    figsize=(15, 50)
)

# Rotate y-tick labels for better visibility
plt.setp(clustermap.ax_heatmap.yaxis.get_majorticklabels(), rotation=0, fontsize=8)

# Adjust the title position and axis labels
clustermap.fig.suptitle('Clustermap of Affinities Between Receptors and Fruity Ligands Grouped by Odor Characteristics', y=1.05)
clustermap.ax_heatmap.set_xlabel('Ligands')
clustermap.ax_heatmap.set_ylabel('Receptors')
plt.savefig("clustermap_fruity_v1.png", format="png")
plt.show()

# %%
## green

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data
merged_green = pd.read_excel('/Users/zoekim/Desktop/l3/aroma_result/green/csv/merged_green_v1.xlsx')
merged_green = merged_green.iloc[:, 1:7]

# Sort by receptor and set receptor as index
merged_green_sorted = merged_green.sort_values(by='Receptor').set_index('Receptor')

# Generate the clustermap with adjusted parameters
plt.figure(figsize=(15, 50))
clustermap = sns.clustermap(
    merged_green_sorted[['Cis 3 Hexenol', 'Cis 3 Hexenyl Acetate', 'Hexanal', 'Isobutyl Acetate', 'Phenoxyacetic Acid']],
    annot=False,
    cmap='coolwarm',
    linewidths=.5,
    linecolor='black',
    figsize=(15, 50)
)

# Rotate y-tick labels for better visibility
plt.setp(clustermap.ax_heatmap.yaxis.get_majorticklabels(), rotation=0, fontsize=8)

# Adjust the title position and axis labels
clustermap.fig.suptitle('Clustermap of Affinities Between Receptors and Green Ligands Grouped by Odor Characteristics', y=1.05)
clustermap.ax_heatmap.set_xlabel('Ligands')
clustermap.ax_heatmap.set_ylabel('Receptors')
plt.savefig("clustermap_green_v1.png", format="png")
plt.show()

# %%
## oriental

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data
merged_oriental = pd.read_excel('/Users/zoekim/Desktop/l3/aroma_result/oriental/csv/merged_oriental_v1.xlsx')
merged_oriental = merged_oriental.iloc[:, 1:7]

# Sort by receptor and set receptor as index
merged_oriental_sorted = merged_oriental.sort_values(by='Receptor').set_index('Receptor')

# Generate the clustermap with adjusted parameters
plt.figure(figsize=(15, 50))
clustermap = sns.clustermap(
    merged_oriental_sorted[['Benzoin', 'Benzyl Benzoate','Cinnamaldehyde', 'Coumarin', 'Vanillin']],
    annot=False,
    cmap='coolwarm',
    linewidths=.5,
    linecolor='black',
    figsize=(15, 50)
)

# Rotate y-tick labels for better visibility
plt.setp(clustermap.ax_heatmap.yaxis.get_majorticklabels(), rotation=0, fontsize=8)

# Adjust the title position and axis labels
clustermap.fig.suptitle('Clustermap of Affinities Between Receptors and Oriental Ligands Grouped by Odor Characteristics', y=1.05)
clustermap.ax_heatmap.set_xlabel('Ligands')
clustermap.ax_heatmap.set_ylabel('Receptors')
plt.savefig("clustermap_oriental_v1.png", format="png")
plt.show()

# %%
## woody

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data
merged_woody = pd.read_excel('/Users/zoekim/Desktop/l3/aroma_result/woody/csv/merged_woody.xlsx')
merged_woody = merged_woody.iloc[:, 1:7]

# Sort by receptor and set receptor as index
merged_woody_sorted = merged_woody.sort_values(by='Receptor').set_index('Receptor')

# Generate the clustermap with adjusted parameters
plt.figure(figsize=(15, 50))
clustermap = sns.clustermap(
    merged_woody_sorted[['1-1-3 Trimethylcyclohexane', 'Benzyl Salicylate','Guaiacol', 'Santalol', 'Vetiverol']],
    annot=False,
    cmap='coolwarm',
    linewidths=.5,
    linecolor='black',
    figsize=(15, 50)
)

# Rotate y-tick labels for better visibility
plt.setp(clustermap.ax_heatmap.yaxis.get_majorticklabels(), rotation=0, fontsize=8)

# Adjust the title position and axis labels
clustermap.fig.suptitle('Clustermap of Affinities Between Receptors and Woody Ligands Grouped by Odor Characteristics', y=1.05)
clustermap.ax_heatmap.set_xlabel('Ligands')
clustermap.ax_heatmap.set_ylabel('Receptors')
plt.savefig("clustermap_woody_v1.png", format="png")
plt.show()
